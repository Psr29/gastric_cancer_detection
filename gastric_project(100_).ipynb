# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Importing all the requires modules and packages

# %%
import os
import cv2
import sys
import json
import random
import imageio
import warnings
import PIL.Image
import imutils
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers import Concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
import imutils
from keras import backend as K
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import ZeroPadding2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import add
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K

# %%
# creating new folders to store images

classes=['normal','stage1','stage2']
path1='/content/gdrive/MyDrive/Gastric_Cancer_Project'
path = os.path.join(path1, 'masks')
os.mkdir(path)

for i in classes:str
    datapath=path+'/'
    path2=os.path.join(datapath, i)
    os.mkdir(path2)

# %% [markdown]
# Generate mask image for normal

# %%
# creating normal mask images from annotation
for root, dirs, files in os.walk("/content/gdrive/MyDrive/Gastric_Cancer_Project/cancer_tissue/normal"):
    for filename in files:
        # print(filename)
        img = np.asarray(PIL.Image.open('/content/gdrive/MyDrive/Gastric_Cancer_Project/cancer_tissue/normal/'+filename))
        img4 = np.zeros((img.shape[0],img.shape[1]))
        cv2.imwrite('/content/gdrive/MyDrive/Gastric_Cancer_Project/masks/normal/%s' % filename,img4)

# %% [markdown]
# create stage-1 mask images from annotation

# %%
# creating stage-1 mask images from annotation
with open("/content/gdrive/MyDrive/Gastric_Cancer_Project/cancerstage1.json", "r") as read_file:
    data = json.load(read_file)

all_file_names=list(data.keys())
# print(len(all_file_names))

files_in_directory = []
for root, dirs, files in os.walk("/content/gdrive/MyDrive/Gastric_Cancer_Project/cancer_tissue/stage1"):
    for filename in files:
        files_in_directory.append(filename)

a=0
for j in range(len(all_file_names)):
    # print(all_file_names[j])
    image_name=data[all_file_names[j]]['filename']

    if image_name in files_in_directory:
        img = np.asarray(PIL.Image.open('/content/gdrive/MyDrive/Gastric_Cancer_Project/cancer_tissue/stage1/'+image_name))
        a=a+1
        # print(a)
    else:
        continue

    if data[all_file_names[j]]['regions'] != {}:

        try:
            shape1_x=data[all_file_names[j]]['regions']['0']['shape_attributes']['all_points_x']
            shape1_y=data[all_file_names[j]]['regions']['0']['shape_attributes']['all_points_y']
        except :
            shape1_x=data[all_file_names[j]]['regions'][0]['shape_attributes']['all_points_x']
            shape1_y=data[all_file_names[j]]['regions'][0]['shape_attributes']['all_points_y']

        ab=np.stack((shape1_x, shape1_y), axis=1)

        mask = np.zeros((img.shape[0],img.shape[1]))
        img3=cv2.drawContours(mask, [ab.astype(int)], -1, 255, -1)
        Mask=mask.astype(np.uint8)
        thresh = 150

        # get threshold image
        ret,thresh_img = cv2.threshold(img, thresh, 255, 0)

        contours, hierarchy = cv2.findContours(Mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

        imagename=image_name.replace("jpg", "png")

        cv2.imwrite('/content/gdrive/MyDrive/Gastric_Cancer_Project/masks/stage1/%s' % imagename,mask.astype(np.uint8))

# %% [markdown]
# create stage-2 mask images from annotation

# %%
# creating stage-2 mask images from annotation
with open("/content/gdrive/MyDrive/Gastric_Cancer_Project/stage2cancer.json", "r") as read_file:
    data = json.load(read_file)

all_file_names=list(data.keys())
# print(len(all_file_names))

Files_in_directory = []
for root, dirs, files in os.walk("/content/gdrive/MyDrive/Gastric_Cancer_Project/cancer_tissue/stage2"):
    for filename in files:
        Files_in_directory.append(filename)
        # print(filename)

a=0
for j in range(len(all_file_names)):
    #print(all_file_names[j])
    image_name=data[all_file_names[j]]['filename']

    if image_name in Files_in_directory:
        img = np.asarray(PIL.Image.open('/content/gdrive/MyDrive/Gastric_Cancer_Project/cancer_tissue/stage2/'+image_name))
        # a=a+1
        # print(a)
    else:
        print(image_name)
        continue

    if data[all_file_names[j]]['regions'] != {}:

        try:
            shape1_x=data[all_file_names[j]]['regions']['0']['shape_attributes']['all_points_x']
            shape1_y=data[all_file_names[j]]['regions']['0']['shape_attributes']['all_points_y']
        except :
            shape1_x=data[all_file_names[j]]['regions'][0]['shape_attributes']['all_points_x']
            shape1_y=data[all_file_names[j]]['regions'][0]['shape_attributes']['all_points_y']

        # fig = plt.figure()
        # plt.imshow(img.astype(np.uint8))
        # plt.scatter(shape1_x,shape1_y,zorder=2,color='red',marker = '.', s= 55)

        ab=np.stack((shape1_x, shape1_y), axis=1)
        img4 = np.zeros((img.shape[0],img.shape[1]))
        img2=cv2.drawContours(img4, [ab.astype(int)], -1, (0,255,0), -1)

        mask = np.zeros((img.shape[0],img.shape[1]))
        img3=cv2.drawContours(mask, [ab.astype(int)], -1, 255, -1)
        Mask=mask.astype(np.uint8)
        thresh = 150

        # get threshold image
        ret,thresh_img = cv2.threshold(img, thresh, 255, 0)

        # find contours
        contours, hierarchy = cv2.findContours(Mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

        imagename=image_name.replace("jpg", "png")

        cv2.imwrite('/content/gdrive/MyDrive/Gastric_Cancer_Project/masks/stage2/%s' % imagename,mask.astype(np.uint8))

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

# %%
# Get train and test IDs
import imageio.v2

classes=['normal','stage1','stage2']


pth = '/content/gdrive/MyDrive/Gastric_Cancer_Project/cancer_tissue'
imgs=[]
for i in classes:
	path=os.path.join(pth, i)
	for img in os.listdir(path):
		if img=='.ipynb_checkpoints':
			continue
		imgs.append(os.path.join(path, img))


mask_path='/content/gdrive/MyDrive/Gastric_Cancer_Project/masks'
masks=[]
for j in classes:
	path1=os.path.join(mask_path, j)
	for mask in os.listdir(path1):
		if mask=='.ipynb_checkpoints':
			continue
		masks.append(os.path.join(path1, mask))


# Get and resize train images and masks
X_train = np.zeros((len(imgs), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(masks), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

print("X_train",X_train.shape)
print("Y_train",Y_train.shape)


print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

for n, img in tqdm(enumerate(sorted(imgs)), total=len(imgs)):
		imgs1 = imageio.v2.imread(img)[:,:,:IMG_CHANNELS]
		# print(imgs1)
		imgs1 = resize(imgs1, (IMG_HEIGHT, IMG_WIDTH),  preserve_range=True)
		X_train[n] = imgs1

i=0
for n, img in tqdm(enumerate(sorted(masks)), total=len(masks)):
	mask_ = imread(img)

	mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant',preserve_range=True), axis=-1)
	# print(mask_ .shape)
	# print(img)
	i=1+i
	Y_train[n] = mask_
# Out:
# X_train (150, 128, 128, 3)
# Y_train (150, 128, 128, 1)
# Getting and resizing train images and masks ...
# <ipython-input-29-6db4cdc71a5d>:29: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(masks), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|██████████| 150/150 [00:11<00:00, 12.50it/s]
# 100%|██████████| 150/150 [01:38<00:00,  1.53it/s]

# %% [markdown]
# Multi-taskNet and GlobalNet model for segmenting images

# %%
# Build Multi-taskNet model
chanDim = 1
stride=(1,1)
reg=0.0001
bnEps=2e-5
bnMom=0.9

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

s = Lambda(lambda x: x / 255) (inputs)

# the first block of the multitaskNet module are the 3x3 CONVs
K=32
bn1 = BatchNormalization(axis=chanDim, epsilon=bnEps,
			momentum=bnMom)(s)
act1 = Activation("relu")(bn1)
conv1 = Conv2D(int(K * 0.25), (1, 1), use_bias=False,
    kernel_regularizer=l2(reg))(act1)

# the second block of the multitaskNet module are the 3x3 CONVs
K=64
bn2 = BatchNormalization(axis=chanDim, epsilon=bnEps,
    momentum=bnMom)(conv1)
act2 = Activation("relu")(bn2)
conv2 = Conv2D(int(K * 0.25), (3, 3), strides=stride,
    padding="same", use_bias=False,
    kernel_regularizer=l2(reg))(act2)

# the third block of the multitaskNet module is another set of 1x1 CONVs
K=128
bn3 = BatchNormalization(axis=chanDim, epsilon=bnEps,
    momentum=bnMom)(conv2)
act3 = Activation("relu")(bn3)
conv3 = Conv2D(K, (1, 1), use_bias=False,
    kernel_regularizer=l2(reg))(act3)

# the forth block of the multitaskNet module is another set of 3x3 CONVs
K=256
bn4 = BatchNormalization(axis=chanDim, epsilon=bnEps,
    momentum=bnMom)(conv1)
act4 = Activation("relu")(bn2)
conv4 = Conv2D(int(K * 0.25), (3, 3), strides=stride,
    padding="same", use_bias=False,
    kernel_regularizer=l2(reg))(act4)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv4)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)

c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
print("The model is defined")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128, 128, 3)  512        ['lambda[0][0]']
#  alization)
#
#  activation (Activation)        (None, 128, 128, 3)  0           ['batch_normalization[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 8)  24          ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 8)  512        ['conv2d[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 128, 128, 8)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  4608        ['activation_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 16  9232        ['conv2d_3[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 16  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 32)   9248        ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 64)   36928       ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 256)    295168      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 256)    590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['conv2d_13[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_17[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_19[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 16  0           ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 1)  17          ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 1,955,545
# Trainable params: 1,955,033
# Non-trainable params: 512
# __________________________________________________________________________________________________
# The model is defined

# %%
# Checkpointer to save best model during training
checkpoint_filepath='/content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5'
checkpointer = ModelCheckpoint(checkpoint_filepath, verbose=1, save_best_only=True,monitor='accuracy',mode="max")

results = model.fit(X_train, Y_train, batch_size=20,callbacks=[checkpointer],epochs=500)
# Out:
# Epoch 1/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3094 - accuracy: 0.8745
# Epoch 1: accuracy improved from -inf to 0.87446, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 15s 270ms/step - loss: 0.3094 - accuracy: 0.8745
# Epoch 2/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2184 - accuracy: 0.9073
# Epoch 2: accuracy improved from 0.87446 to 0.90557, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 153ms/step - loss: 0.2208 - accuracy: 0.9056
# Epoch 3/500
# 8/8 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.9338
# Epoch 3: accuracy improved from 0.90557 to 0.93378, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 119ms/step - loss: 0.1667 - accuracy: 0.9338
# Epoch 4/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1579 - accuracy: 0.9359
# Epoch 4: accuracy improved from 0.93378 to 0.93575, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 117ms/step - loss: 0.1578 - accuracy: 0.9357
# Epoch 5/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1574 - accuracy: 0.9394
# Epoch 5: accuracy improved from 0.93575 to 0.93912, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 112ms/step - loss: 0.1572 - accuracy: 0.9391
# Epoch 6/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1469 - accuracy: 0.9463
# Epoch 6: accuracy improved from 0.93912 to 0.94834, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1425 - accuracy: 0.9483
# Epoch 7/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1378 - accuracy: 0.9487
# Epoch 7: accuracy improved from 0.94834 to 0.94867, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1376 - accuracy: 0.9487
# Epoch 8/500
# 8/8 [==============================] - ETA: 0s - loss: 0.1417 - accuracy: 0.9447
# Epoch 8: accuracy did not improve from 0.94867
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1417 - accuracy: 0.9447
# Epoch 9/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1231 - accuracy: 0.9541
# Epoch 9: accuracy improved from 0.94867 to 0.95161, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 115ms/step - loss: 0.1282 - accuracy: 0.9516
# Epoch 10/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1218 - accuracy: 0.9539
# Epoch 10: accuracy improved from 0.95161 to 0.95508, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 110ms/step - loss: 0.1191 - accuracy: 0.9551
# Epoch 11/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1158 - accuracy: 0.9584
# Epoch 11: accuracy improved from 0.95508 to 0.95935, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1144 - accuracy: 0.9593
# Epoch 12/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1186 - accuracy: 0.9577
# Epoch 12: accuracy did not improve from 0.95935
# 8/8 [==============================] - 1s 74ms/step - loss: 0.1259 - accuracy: 0.9548
# Epoch 13/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1437 - accuracy: 0.9459
# Epoch 13: accuracy did not improve from 0.95935
# 8/8 [==============================] - 1s 74ms/step - loss: 0.1387 - accuracy: 0.9479
# Epoch 14/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1346 - accuracy: 0.9504
# Epoch 14: accuracy did not improve from 0.95935
# 8/8 [==============================] - 1s 74ms/step - loss: 0.1329 - accuracy: 0.9508
# Epoch 15/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1229 - accuracy: 0.9585
# Epoch 15: accuracy did not improve from 0.95935
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1235 - accuracy: 0.9579
# Epoch 16/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1208 - accuracy: 0.9550
# Epoch 16: accuracy did not improve from 0.95935
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1204 - accuracy: 0.9554
# Epoch 17/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0966 - accuracy: 0.9649
# Epoch 17: accuracy improved from 0.95935 to 0.96388, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0998 - accuracy: 0.9639
# Epoch 18/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1041 - accuracy: 0.9614
# Epoch 18: accuracy did not improve from 0.96388
# 8/8 [==============================] - 1s 74ms/step - loss: 0.1018 - accuracy: 0.9625
# Epoch 19/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0936 - accuracy: 0.9641
# Epoch 19: accuracy improved from 0.96388 to 0.96490, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 119ms/step - loss: 0.0929 - accuracy: 0.9649
# Epoch 20/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0911 - accuracy: 0.9662
# Epoch 20: accuracy improved from 0.96490 to 0.96531, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 119ms/step - loss: 0.0946 - accuracy: 0.9653
# Epoch 21/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0936 - accuracy: 0.9646
# Epoch 21: accuracy did not improve from 0.96531
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0982 - accuracy: 0.9631
# Epoch 22/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1049 - accuracy: 0.9589
# Epoch 22: accuracy did not improve from 0.96531
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1033 - accuracy: 0.9598
# Epoch 23/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0993 - accuracy: 0.9620
# Epoch 23: accuracy did not improve from 0.96531
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0987 - accuracy: 0.9623
# Epoch 24/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0930 - accuracy: 0.9646
# Epoch 24: accuracy did not improve from 0.96531
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0942 - accuracy: 0.9649
# Epoch 25/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0846 - accuracy: 0.9678
# Epoch 25: accuracy improved from 0.96531 to 0.96702, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0862 - accuracy: 0.9670
# Epoch 26/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0841 - accuracy: 0.9672
# Epoch 26: accuracy improved from 0.96702 to 0.96856, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0810 - accuracy: 0.9686
# Epoch 27/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0803 - accuracy: 0.9684
# Epoch 27: accuracy improved from 0.96856 to 0.96880, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0794 - accuracy: 0.9688
# Epoch 28/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0766 - accuracy: 0.9696
# Epoch 28: accuracy improved from 0.96880 to 0.96898, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 140ms/step - loss: 0.0782 - accuracy: 0.9690
# Epoch 29/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0832 - accuracy: 0.9675
# Epoch 29: accuracy did not improve from 0.96898
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0820 - accuracy: 0.9681
# Epoch 30/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0807 - accuracy: 0.9682
# Epoch 30: accuracy did not improve from 0.96898
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0819 - accuracy: 0.9677
# Epoch 31/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0821 - accuracy: 0.9668
# Epoch 31: accuracy did not improve from 0.96898
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0792 - accuracy: 0.9681
# Epoch 32/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0797 - accuracy: 0.9673
# Epoch 32: accuracy did not improve from 0.96898
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0776 - accuracy: 0.9683
# Epoch 33/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0816 - accuracy: 0.9687
# Epoch 33: accuracy improved from 0.96898 to 0.96900, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0806 - accuracy: 0.9690
# Epoch 34/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0761 - accuracy: 0.9706
# Epoch 34: accuracy improved from 0.96900 to 0.97133, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0753 - accuracy: 0.9713
# Epoch 35/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0683 - accuracy: 0.9739
# Epoch 35: accuracy improved from 0.97133 to 0.97392, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 114ms/step - loss: 0.0683 - accuracy: 0.9739
# Epoch 36/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0713 - accuracy: 0.9720
# Epoch 36: accuracy did not improve from 0.97392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0706 - accuracy: 0.9727
# Epoch 37/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0777 - accuracy: 0.9689
# Epoch 37: accuracy did not improve from 0.97392
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0757 - accuracy: 0.9698
# Epoch 38/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0754 - accuracy: 0.9709
# Epoch 38: accuracy did not improve from 0.97392
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0732 - accuracy: 0.9718
# Epoch 39/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0678 - accuracy: 0.9726
# Epoch 39: accuracy did not improve from 0.97392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0681 - accuracy: 0.9729
# Epoch 40/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0676 - accuracy: 0.9738
# Epoch 40: accuracy did not improve from 0.97392
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0683 - accuracy: 0.9735
# Epoch 41/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0670 - accuracy: 0.9735
# Epoch 41: accuracy improved from 0.97392 to 0.97489, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 120ms/step - loss: 0.0644 - accuracy: 0.9749
# Epoch 42/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0642 - accuracy: 0.9763
# Epoch 42: accuracy improved from 0.97489 to 0.97606, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0647 - accuracy: 0.9761
# Epoch 43/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0678 - accuracy: 0.9734
# Epoch 43: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0689 - accuracy: 0.9733
# Epoch 44/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0665 - accuracy: 0.9737
# Epoch 44: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0659 - accuracy: 0.9739
# Epoch 45/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0643 - accuracy: 0.9766
# Epoch 45: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0702 - accuracy: 0.9747
# Epoch 46/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0786 - accuracy: 0.9705
# Epoch 46: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0762 - accuracy: 0.9716
# Epoch 47/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0718 - accuracy: 0.9735
# Epoch 47: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0716 - accuracy: 0.9734
# Epoch 48/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0713 - accuracy: 0.9711
# Epoch 48: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0702 - accuracy: 0.9718
# Epoch 49/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0647 - accuracy: 0.9747
# Epoch 49: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0619 - accuracy: 0.9760
# Epoch 50/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0686 - accuracy: 0.9742
# Epoch 50: accuracy did not improve from 0.97606
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0656 - accuracy: 0.9753
# Epoch 51/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0592 - accuracy: 0.9768
# Epoch 51: accuracy improved from 0.97606 to 0.97679, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0593 - accuracy: 0.9768
# Epoch 52/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0550 - accuracy: 0.9780
# Epoch 52: accuracy improved from 0.97679 to 0.97834, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0542 - accuracy: 0.9783
# Epoch 53/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0521 - accuracy: 0.9796
# Epoch 53: accuracy improved from 0.97834 to 0.97893, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0537 - accuracy: 0.9789
# Epoch 54/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0611 - accuracy: 0.9759
# Epoch 54: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0606 - accuracy: 0.9761
# Epoch 55/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0560 - accuracy: 0.9787
# Epoch 55: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0566 - accuracy: 0.9785
# Epoch 56/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0506 - accuracy: 0.9808
# Epoch 56: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0756 - accuracy: 0.9780
# Epoch 57/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0937 - accuracy: 0.9617
# Epoch 57: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 78ms/step - loss: 0.1008 - accuracy: 0.9584
# Epoch 58/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0782 - accuracy: 0.9683
# Epoch 58: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0788 - accuracy: 0.9684
# Epoch 59/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0749 - accuracy: 0.9722
# Epoch 59: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0769 - accuracy: 0.9710
# Epoch 60/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0676 - accuracy: 0.9731
# Epoch 60: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0683 - accuracy: 0.9733
# Epoch 61/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0633 - accuracy: 0.9750
# Epoch 61: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0638 - accuracy: 0.9749
# Epoch 62/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0671 - accuracy: 0.9735
# Epoch 62: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0677 - accuracy: 0.9735
# Epoch 63/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0728 - accuracy: 0.9716
# Epoch 63: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0747 - accuracy: 0.9712
# Epoch 64/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0680 - accuracy: 0.9746
# Epoch 64: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0665 - accuracy: 0.9749
# Epoch 65/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0573 - accuracy: 0.9782
# Epoch 65: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0563 - accuracy: 0.9786
# Epoch 66/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0531 - accuracy: 0.9790
# Epoch 66: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0548 - accuracy: 0.9781
# Epoch 67/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0595 - accuracy: 0.9767
# Epoch 67: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0592 - accuracy: 0.9767
# Epoch 68/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0620 - accuracy: 0.9765
# Epoch 68: accuracy did not improve from 0.97893
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0599 - accuracy: 0.9774
# Epoch 69/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0531 - accuracy: 0.9787
# Epoch 69: accuracy improved from 0.97893 to 0.97907, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 2s 245ms/step - loss: 0.0526 - accuracy: 0.9791
# Epoch 70/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0612 - accuracy: 0.9763
# Epoch 70: accuracy did not improve from 0.97907
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0625 - accuracy: 0.9758
# Epoch 71/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0556 - accuracy: 0.9792
# Epoch 71: accuracy did not improve from 0.97907
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0571 - accuracy: 0.9784
# Epoch 72/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0523 - accuracy: 0.9793
# Epoch 72: accuracy improved from 0.97907 to 0.97941, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0521 - accuracy: 0.9794
# Epoch 73/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0550 - accuracy: 0.9797
# Epoch 73: accuracy did not improve from 0.97941
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0558 - accuracy: 0.9791
# Epoch 74/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0504 - accuracy: 0.9807
# Epoch 74: accuracy improved from 0.97941 to 0.98090, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0498 - accuracy: 0.9809
# Epoch 75/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0482 - accuracy: 0.9814
# Epoch 75: accuracy improved from 0.98090 to 0.98145, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 119ms/step - loss: 0.0479 - accuracy: 0.9815
# Epoch 76/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0394 - accuracy: 0.9849
# Epoch 76: accuracy improved from 0.98145 to 0.98259, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 122ms/step - loss: 0.0464 - accuracy: 0.9826
# Epoch 77/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0487 - accuracy: 0.9806
# Epoch 77: accuracy did not improve from 0.98259
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0478 - accuracy: 0.9811
# Epoch 78/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0395 - accuracy: 0.9840
# Epoch 78: accuracy improved from 0.98259 to 0.98400, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 119ms/step - loss: 0.0397 - accuracy: 0.9840
# Epoch 79/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0363 - accuracy: 0.9865
# Epoch 79: accuracy improved from 0.98400 to 0.98648, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0362 - accuracy: 0.9865
# Epoch 80/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0394 - accuracy: 0.9850
# Epoch 80: accuracy did not improve from 0.98648
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0390 - accuracy: 0.9851
# Epoch 81/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0347 - accuracy: 0.9871
# Epoch 81: accuracy did not improve from 0.98648
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0365 - accuracy: 0.9864
# Epoch 82/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0377 - accuracy: 0.9855
# Epoch 82: accuracy did not improve from 0.98648
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0364 - accuracy: 0.9861
# Epoch 83/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0350 - accuracy: 0.9863
# Epoch 83: accuracy did not improve from 0.98648
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0349 - accuracy: 0.9864
# Epoch 84/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0310 - accuracy: 0.9882
# Epoch 84: accuracy improved from 0.98648 to 0.98741, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0327 - accuracy: 0.9874
# Epoch 85/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0281 - accuracy: 0.9886
# Epoch 85: accuracy improved from 0.98741 to 0.98840, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0288 - accuracy: 0.9884
# Epoch 86/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0366 - accuracy: 0.9871
# Epoch 86: accuracy did not improve from 0.98840
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0386 - accuracy: 0.9862
# Epoch 87/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0391 - accuracy: 0.9851
# Epoch 87: accuracy did not improve from 0.98840
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0379 - accuracy: 0.9855
# Epoch 88/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0348 - accuracy: 0.9865
# Epoch 88: accuracy did not improve from 0.98840
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0358 - accuracy: 0.9860
# Epoch 89/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0327 - accuracy: 0.9877
# Epoch 89: accuracy did not improve from 0.98840
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0329 - accuracy: 0.9877
# Epoch 90/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0311 - accuracy: 0.9880
# Epoch 90: accuracy did not improve from 0.98840
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0303 - accuracy: 0.9883
# Epoch 91/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0327 - accuracy: 0.9872
# Epoch 91: accuracy did not improve from 0.98840
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0312 - accuracy: 0.9878
# Epoch 92/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.
saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 120ms/step - loss: 0.0158 - accuracy: 0.9939
# Epoch 114/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0159 - accuracy: 0.9938
# Epoch 114: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0160 - accuracy: 0.9938
# Epoch 115/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0169 - accuracy: 0.9934
# Epoch 115: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0163 - accuracy: 0.9937
# Epoch 116/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0152 - accuracy: 0.9941
# Epoch 116: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0190 - accuracy: 0.9928
# Epoch 117/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0626 - accuracy: 0.9779
# Epoch 117: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0709 - accuracy: 0.9763
# Epoch 118/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0540 - accuracy: 0.9809
# Epoch 118: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0530 - accuracy: 0.9813
# Epoch 119/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0521 - accuracy: 0.9829
# Epoch 119: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0510 - accuracy: 0.9831
# Epoch 120/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0386 - accuracy: 0.9850
# Epoch 120: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0410 - accuracy: 0.9842
# Epoch 121/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0409 - accuracy: 0.9845
# Epoch 121: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0401 - accuracy: 0.9847
# Epoch 122/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0379 - accuracy: 0.9857
# Epoch 122: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0380 - accuracy: 0.9856
# Epoch 123/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0392 - accuracy: 0.9856
# Epoch 123: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0393 - accuracy: 0.9855
# Epoch 124/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0349 - accuracy: 0.9874
# Epoch 124: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0361 - accuracy: 0.9870
# Epoch 125/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0267 - accuracy: 0.9901
# Epoch 125: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0269 - accuracy: 0.9900
# Epoch 126/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0244 - accuracy: 0.9904
# Epoch 126: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0239 - accuracy: 0.9906
# Epoch 127/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0237 - accuracy: 0.9912
# Epoch 127: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0248 - accuracy: 0.9907
# Epoch 128/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0470 - accuracy: 0.9836
# Epoch 128: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0480 - accuracy: 0.9829
# Epoch 129/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0359 - accuracy: 0.9863
# Epoch 129: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0376 - accuracy: 0.9858
# Epoch 130/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0470 - accuracy: 0.9856
# Epoch 130: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0457 - accuracy: 0.9858
# Epoch 131/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0301 - accuracy: 0.9886
# Epoch 131: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0306 - accuracy: 0.9885
# Epoch 132/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0244 - accuracy: 0.9906
# Epoch 132: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0291 - accuracy: 0.9893
# Epoch 133/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0391 - accuracy: 0.9859
# Epoch 133: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0396 - accuracy: 0.9857
# Epoch 134/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0376 - accuracy: 0.9862
# Epoch 134: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0375 - accuracy: 0.9862
# Epoch 135/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0335 - accuracy: 0.9882
# Epoch 135: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0332 - accuracy: 0.9883
# Epoch 136/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0243 - accuracy: 0.9907
# Epoch 136: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0241 - accuracy: 0.9908
# Epoch 137/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0218 - accuracy: 0.9917
# Epoch 137: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0214 - accuracy: 0.9919
# Epoch 138/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0194 - accuracy: 0.9926
# Epoch 138: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0196 - accuracy: 0.9925
# Epoch 139/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0202 - accuracy: 0.9921
# Epoch 139: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0199 - accuracy: 0.9922
# Epoch 140/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0175 - accuracy: 0.9933
# Epoch 140: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0184 - accuracy: 0.9931
# Epoch 141/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0200 - accuracy: 0.9923
# Epoch 141: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0194 - accuracy: 0.9925
# Epoch 142/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0193 - accuracy: 0.9925
# Epoch 142: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0194 - accuracy: 0.9924
# Epoch 143/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0172 - accuracy: 0.9934
# Epoch 143: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0172 - accuracy: 0.9934
# Epoch 144/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0162 - accuracy: 0.9937
# Epoch 144: accuracy did not improve from 0.99392
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0163 - accuracy: 0.9937
# Epoch 145/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0151 - accuracy: 0.9942
# Epoch 145: accuracy improved from 0.99392 to 0.99416, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] -
accuracy did not improve from 0.99483
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0154 - accuracy: 0.9942
# Epoch 174/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0148 - accuracy: 0.9943
# Epoch 174: accuracy did not improve from 0.99483
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0145 - accuracy: 0.9945
# Epoch 175/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0144 - accuracy: 0.9945
# Epoch 175: accuracy did not improve from 0.99483
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0144 - accuracy: 0.9945
# Epoch 176/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0139 - accuracy: 0.9947
# Epoch 176: accuracy did not improve from 0.99483
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0141 - accuracy: 0.9946
# Epoch 177/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0134 - accuracy: 0.9949
# Epoch 177: accuracy did not improve from 0.99483
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0136 - accuracy: 0.9948
# Epoch 178/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0138 - accuracy: 0.9947
# Epoch 178: accuracy did not improve from 0.99483
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0137 - accuracy: 0.9948
# Epoch 179/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0129 - accuracy: 0.9951
# Epoch 179: accuracy improved from 0.99483 to 0.99512, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 2s 215ms/step - loss: 0.0129 - accuracy: 0.9951
# Epoch 180/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0133 - accuracy: 0.9949
# Epoch 180: accuracy did not improve from 0.99512
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0130 - accuracy: 0.9950
# Epoch 181/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0129 - accuracy: 0.9952
# Epoch 181: accuracy did not improve from 0.99512
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0130 - accuracy: 0.9951
# Epoch 182/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0127 - accuracy: 0.9953
# Epoch 182: accuracy improved from 0.99512 to 0.99523, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0128 - accuracy: 0.9952
# Epoch 183/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0126 - accuracy: 0.9952
# Epoch 183: accuracy improved from 0.99523 to 0.99535, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0122 - accuracy: 0.9954
# Epoch 184/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0122 - accuracy: 0.9954
# Epoch 184: accuracy improved from 0.99535 to 0.99536, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0123 - accuracy: 0.9954
# Epoch 185/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0118 - accuracy: 0.9956
# Epoch 185: accuracy improved from 0.99536 to 0.99550, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0120 - accuracy: 0.9955
# Epoch 186/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0124 - accuracy: 0.9953
# Epoch 186: accuracy did not improve from 0.99550
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0124 - accuracy: 0.9953
# Epoch 187/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0128 - accuracy: 0.9954
# Epoch 187: accuracy improved from 0.99550 to 0.99551, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0124 - accuracy: 0.9955
# Epoch 188/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0120 - accuracy: 0.9955
# Epoch 188: accuracy did not improve from 0.99551
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0123 - accuracy: 0.9954
# Epoch 189/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0117 - accuracy: 0.9955
# Epoch 189: accuracy did not improve from 0.99551
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0118 - accuracy: 0.9955
# Epoch 190/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0120 - accuracy: 0.9955
# Epoch 190: accuracy improved from 0.99551 to 0.99555, saving model to /content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5
# ...
# Epoch 433/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0146 - accuracy: 0.9949
# Epoch 433: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0143 - accuracy: 0.9950
# Epoch 434/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0143 - accuracy: 0.9949
# Epoch 434: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0139 - accuracy: 0.9951
# Epoch 435/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0102 - accuracy: 0.9963
# Epoch 435: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0104 - accuracy: 0.9962
# Epoch 436/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0102 - accuracy: 0.9963
# Epoch 436: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0104 - accuracy: 0.9963
# Epoch 437/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0083 - accuracy: 0.9970
# Epoch 437: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0086 - accuracy: 0.9969
# Epoch 438/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0076 - accuracy: 0.9972
# Epoch 438: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0078 - accuracy: 0.9972
# Epoch 439/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0081 - accuracy: 0.9972
# Epoch 439: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0079 - accuracy: 0.9973
# Epoch 440/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0069 - accuracy: 0.9975
# Epoch 440: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0070 - accuracy: 0.9975
# Epoch 441/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0068 - accuracy: 0.9976
# Epoch 441: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0069 - accuracy: 0.9975
# Epoch 442/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0068 - accuracy: 0.9976
# Epoch 442: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0067 - accuracy: 0.9976
# Epoch 443/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0065 - accuracy: 0.9977
# Epoch 443: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0064 - accuracy: 0.9978
# Epoch 444/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0063 - accuracy: 0.9978
# Epoch 444: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0064 - accuracy: 0.9977
# Epoch 445/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0062 - accuracy: 0.9979
# Epoch 445: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0061 - accuracy: 0.9979
# Epoch 446/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0062 - accuracy: 0.9978
# Epoch 446: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0062 - accuracy: 0.9978
# Epoch 447/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0058 - accuracy: 0.9980
# Epoch 447: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0058 - accuracy: 0.9980
# Epoch 448/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0057 - accuracy: 0.9980
# Epoch 448: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0057 - accuracy: 0.9980
# Epoch 449/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0059 - accuracy: 0.9980
# Epoch 449: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0058 - accuracy: 0.9980
# Epoch 450/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0054 - accuracy: 0.9981
# Epoch 450: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 451/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0056 - accuracy: 0.9981
# Epoch 451: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0056 - accuracy: 0.9981
# Epoch 452/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0055 - accuracy: 0.9981
# Epoch 452: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0057 - accuracy: 0.9980
# Epoch 453/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0054 - accuracy: 0.9981
# Epoch 453: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 454/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 0.9982
# Epoch 454: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0053 - accuracy: 0.9982
# Epoch 455/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0059 - accuracy: 0.9979
# Epoch 455: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0057 - accuracy: 0.9980
# Epoch 456/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0055 - accuracy: 0.9981
# Epoch 456: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0053 - accuracy: 0.9982
# Epoch 457/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0055 - accuracy: 0.9981
# Epoch 457: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 458/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0054 - accuracy: 0.9981
# Epoch 458: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0054 - accuracy: 0.9981
# Epoch 459/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0054 - accuracy: 0.9982
# Epoch 459: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 460/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 0.9982
# Epoch 460: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0052 - accuracy: 0.9982
# Epoch 461/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0053 - accuracy: 0.9982
# Epoch 461: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0052 - accuracy: 0.9982
# Epoch 462/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 0.9983
# Epoch 462: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 463/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 0.9983
# Epoch 463: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0051 - accuracy: 0.9983
# Epoch 464/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0049 - accuracy: 0.9983
# Epoch 464: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0049 - accuracy: 0.9983
# Epoch 465/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0048 - accuracy: 0.9984
# Epoch 465: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 466/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0047 - accuracy: 0.9985
# Epoch 466: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 467/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0048 - accuracy: 0.9984
# Epoch 467: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 468/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0048 - accuracy: 0.9984
# Epoch 468: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 469/500
# 8/8 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9984
# Epoch 469: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0047 - accuracy: 0.9984
# Epoch 470/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0045 - accuracy: 0.9985
# Epoch 470: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0052 - accuracy: 0.9984
# Epoch 471/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0050 - accuracy: 0.9983
# Epoch 471: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0050 - accuracy: 0.9983
# Epoch 472/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0054 - accuracy: 0.9982
# Epoch 472: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 473/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0051 - accuracy: 0.9983
# Epoch 473: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0051 - accuracy: 0.9983
# Epoch 474/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 0.9983
# Epoch 474: accuracy did not improve from 0.99843
# 8/8 [==============================] - 1s 75ms/step - loss: 0.
500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0069 - accuracy: 0.9976
# Epoch 498: accuracy did not improve from 0.99853
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0068 - accuracy: 0.9976
# Epoch 499/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0058 - accuracy: 0.9980
# Epoch 499: accuracy did not improve from 0.99853
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0062 - accuracy: 0.9979
# Epoch 500/500
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0057 - accuracy: 0.9980
# Epoch 500: accuracy did not improve from 0.99853
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0057 - accuracy: 0.9981

# %% [markdown]
# code for classification of cancer images

# %%
# import necessary layers
from tensorflow.keras.layers import Input, Conv2D , Dropout, MaxPool2D, Flatten, Dense
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os
import imutils
import matplotlib.pyplot as plt
import sys
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

segmask_path='/content/gdrive/MyDrive/Implementation/gastric cancer/segmentation_masks'
segmaskfiles=[]
for img in os.listdir(segmask_path):
    segmaskfiles.append(os.path.join(segmask_path ,img))


tmp_model_name = "/content/gdrive/MyDrive/Implementation/gastric cancer/tmp.h5"
INPUT_SIZE = 64
BATCH_SIZE = 16


class SimplePreprocessor:
	def __init__(self, width, height, inter=cv2.INTER_AREA):
		# store the target image width, height, and interpolation
		# method used when resizing
		self.width = width
		self.height = height
		self.inter = inter

	def preprocess(self, image):
		# resize the image to a fixed size, ignoring the aspect
		# ratio
		return cv2.resize(image, (self.width, self.height),
			interpolation=self.inter)

class AspectAwarePreprocessor:
	def __init__(self, width, height, inter=cv2.INTER_AREA):
		# store the target image width, height, and interpolation
		# method used when resizing
		self.width = width
		self.height = height
		self.inter = inter

	def preprocess(self, image):
		# grab the dimensions of the image and then initialize
		# the deltas to use when cropping
		(h, w) = image.shape[:2]
		dW = 0
		dH = 0

		# if the width is smaller than the height, then resize
		# along the width (i.e., the smaller dimension) and then
		# update the deltas to crop the height to the desired
		# dimension
		if w < h:
			image = imutils.resize(image, width=self.width,
				inter=self.inter)
			dH = int((image.shape[0] - self.height) / 2.0)

		# otherwise, the height is smaller than the width so
		# resize along the height and then update the deltas
		# crop along the width
		else:
			image = imutils.resize(image, height=self.height,
				inter=self.inter)
			dW = int((image.shape[1] - self.width) / 2.0)

		# now that our images have been resized, we need to
		# re-grab the width and height, followed by performing
		# the crop
		(h, w) = image.shape[:2]
		image = image[dH:h - dH, dW:w - dW]

		# finally, resize the image to the provided spatial
		# dimensions to ensure our output image is always a fixed
		# size
		return cv2.resize(image, (self.width, self.height),
			interpolation=self.inter)

class ImageToArrayPreprocessor:
	def __init__(self, dataFormat=None):
		# store the image data format
		self.dataFormat = dataFormat

	def preprocess(self, image):
		# apply the Keras utility function that correctly rearranges
		# the dimensions of the image
		return img_to_array(image, data_format=self.dataFormat)

class SimpleDatasetLoader:
	def __init__(self, preprocessors=None):
		# store the image preprocessor
		self.preprocessors = preprocessors

		# if the preprocessors are None, initialize them as an
		# empty list
		if self.preprocessors is None:
			self.preprocessors = []

	def load(self, imagePaths, verbose=-1):
		# initialize the list of features and labels
		data = []
		labels = []

		# loop over the input images
		for (i, imagePath) in enumerate(imagePaths):
			# load the image and extract the class label assuming
			# that our path has the following format:
			# /path/to/dataset/{class}/{image}.jpg
			image = cv2.imread(imagePath)


			label = imagePath.split(os.path.sep)[-2]
			# check to see if our preprocessors are not None
			if self.preprocessors is not None:
				# loop over the preprocessors and apply each to
				# the image
				for p in self.preprocessors:
					image = p.preprocess(image)

			# treat our processed image as a "feature vector"
			# by updating the data list followed by the labels
			data.append(image)
			labels.append(label)

			# show an update every `verbose` images
			if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
				print("[INFO] processed {}/{}".format(i + 1,
					len(imagePaths)))

		# return a tuple of the data and labels
		return (np.array(data), np.array(labels))


classNames = [pt.split(os.path.sep)[-2] for pt in masks]
classNames = [str(x) for x in np.unique(classNames)]

# initialize the image preprocessors
aap = AspectAwarePreprocessor(64, 64)
iap = ImageToArrayPreprocessor()

# load the dataset from disk then scale the raw pixel intensities
# to the range [0, 1]
sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
(data, labels) = sdl.load(masks, verbose=500)
data = data.astype("float") / 255.0

# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.25, random_state=42)

# convert the labels from integers to vectors
trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)

# %% [markdown]
# FusionNet

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

import tensorflow as tf
from keras import backend
from keras.applications import imagenet_utils
from keras.engine import training
from keras.layers import VersionAwareLayers
from keras.utils import data_utils
from keras.utils import layer_utils
from tensorflow.python.util.tf_export import keras_export

WEIGHTS_PATH = ('https://storage.googleapis.com/tensorflow/keras-applications/'
                'vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5')
WEIGHTS_PATH_NO_TOP = ('https://storage.googleapis.com/tensorflow/'
                       'keras-applications/vgg16/'
                       'vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')

layers = VersionAwareLayers()

class FCHeadNet:
	@staticmethod
	def build(baseModel, classes, D):
		# initialize the head model that will be placed on top of
		# the base, then add a FC layer
		headModel = baseModel.output
		headModel = Flatten(name="flatten")(headModel)
		headModel = Dense(D, activation="relu")(headModel)
		headModel = Dropout(0.5)(headModel)

		# add a softmax layer
		headModel = Dense(classes, activation="softmax")(headModel)

		# return the model
		return headModel

def VGG16(
    include_top=True,
    weights='imagenet',
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation='softmax'):

  if not (weights in {'imagenet', None} or tf.io.gfile.exists(weights)):
    raise ValueError(
        'The `weights` argument should be either '
        '`None` (random initialization), `imagenet` '
        '(pre-training on ImageNet), '
        'or the path to the weights file to be loaded.  Received: '
        f'weights={weights}')

  if weights == 'imagenet' and include_top and classes != 1000:
    raise ValueError('If using `weights` as `"imagenet"` with `include_top` '
                     'as true, `classes` should be 1000.  '
                     f'Received `classes={classes}`')
  # Determine proper input shape
  input_shape = imagenet_utils.obtain_input_shape(
      input_shape,
      default_size=224,
      min_size=32,
      data_format=backend.image_data_format(),
      require_flatten=include_top,
      weights=weights)

  if input_tensor is None:
    img_input = layers.Input(shape=input_shape)
  else:
    if not backend.is_keras_tensor(input_tensor):
      img_input = layers.Input(tensor=input_tensor, shape=input_shape)
    else:
      img_input = input_tensor
  # Block 1
  x = layers.Conv2D(
      64, (3, 3), activation='relu', padding='same', name='block1_conv1')(
          img_input)
  x = layers.Conv2D(
      64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
  x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

  # Block 2
  x = layers.Conv2D(
      128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
  x = layers.Conv2D(
      128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
  x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

  # Block 3
  x = layers.Conv2D(
      256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
  x = layers.Conv2D(
      256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
  x = layers.Conv2D(
      256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
  x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

  # Block 4
  x = layers.Conv2D(
      512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
  x = layers.Conv2D(
      512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
  x = layers.Conv2D(
      512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
  x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

  # Block 5
  x = layers.Conv2D(
      512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
  x = layers.Conv2D(
      512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
  x = layers.Conv2D(
      512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
  x = layers.MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

  if include_top:
    # Classification block
    x = layers.Flatten(name='flatten')(x)
    x = layers.Dense(4096, activation='relu', name='fc1')(x)
    x = layers.Dense(4096, activation='relu', name='fc2')(x)

    imagenet_utils.validate_activation(classifier_activation, weights)
    x = layers.Dense(classes, activation=classifier_activation,
                     name='predictions')(x)
  else:
    if pooling == 'avg':
      x = layers.GlobalAveragePooling2D()(x)
    elif pooling == 'max':
      x = layers.GlobalMaxPooling2D()(x)

  # Ensure that the model takes into account
  # any potential predecessors of `input_tensor`.
  if input_tensor is not None:
    inputs = layer_utils.get_source_inputs(input_tensor)
  else:
    inputs = img_input
  # Create model.
  model = training.Model(inputs, x, name='vgg16')


  return model

# %%
baseModel = VGG16(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(64, 64, 3)))

# initialize the new head of the network, a set of FC layers
# followed by a softmax classifier
headModel = FCHeadNet.build(baseModel, len(classNames), 256)

# place the head FC model on top of the base model -- this will
# become the actual model we will train
model = Model(inputs=baseModel.input, outputs=headModel)

# loop over all layers in the base model and freeze them so they
# will *not* be updated during the training process
for layer in baseModel.layers:
	layer.trainable = False

# compile our model (this needs to be done after our setting our
# layers to being non-trainable
print("[INFO] compiling model...")
opt = Adam(lr=0.001)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])

print("[INFO] training network...")
H = model.fit(trainX, trainY, validation_data=(testX, testY),
  batch_size=32, epochs=100, verbose=1)

print("[INFO] evaluating after fine-tuning...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=classNames))

# save the model to disk
print("[INFO] serializing model...")
m = model
m.save(tmp_model_name)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step
# 58900480/58889256 [==============================] - 2s 0us/step
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#
100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0465 - accuracy: 0.9911 - val_loss: 0.1610 - val_accuracy: 0.9474
# Epoch 77/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9474
# Epoch 78/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0367 - accuracy: 0.9821 - val_loss: 0.1750 - val_accuracy: 0.9474
# Epoch 79/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0282 - accuracy: 0.9821 - val_loss: 0.1645 - val_accuracy: 0.9474
# Epoch 80/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0276 - accuracy: 0.9911 - val_loss: 0.1650 - val_accuracy: 0.9474
# Epoch 81/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0224 - accuracy: 0.9911 - val_loss: 0.1683 - val_accuracy: 0.9474
# Epoch 82/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0235 - accuracy: 0.9911 - val_loss: 0.1667 - val_accuracy: 0.9474
# Epoch 83/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0292 - accuracy: 0.9911 - val_loss: 0.1666 - val_accuracy: 0.9474
# Epoch 84/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9474
# Epoch 85/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0196 - accuracy: 0.9911 - val_loss: 0.1663 - val_accuracy: 0.9474
# Epoch 86/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9474
# Epoch 87/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0261 - accuracy: 0.9911 - val_loss: 0.1682 - val_accuracy: 0.9474
# Epoch 88/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9474
# Epoch 89/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0265 - accuracy: 0.9821 - val_loss: 0.1727 - val_accuracy: 0.9474
# Epoch 90/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0144 - accuracy: 0.9911 - val_loss: 0.1740 - val_accuracy: 0.9737
# Epoch 91/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0347 - accuracy: 0.9821 - val_loss: 0.1836 - val_accuracy: 0.9474
# Epoch 92/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9474
# Epoch 93/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.1834 - val_accuracy: 0.9474
# Epoch 94/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9474
# Epoch 95/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9474
# Epoch 96/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0190 - accuracy: 0.9911 - val_loss: 0.1905 - val_accuracy: 0.9474
# Epoch 97/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.1910 - val_accuracy: 0.9474
# Epoch 98/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0243 - accuracy: 0.9821 - val_loss: 0.2008 - val_accuracy: 0.9474
# Epoch 99/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0197 - accuracy: 0.9911 - val_loss: 0.2016 - val_accuracy: 0.9474
# Epoch 100/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9474
# [INFO] evaluating after fine-tuning...
#               precision    recall  f1-score   support
#
#       normal       1.00      1.00      1.00        11
#       stage1       0.93      0.93      0.93        15
#       stage2       0.92      0.92      0.92        12
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.95      0.95        38
# weighted avg       0.95      0.95      0.95        38
#
# [INFO] serializing model...

# %% [markdown]
# Prediciton

# %%
class AspectAwarePreprocessor:
	def __init__(self, width, height, inter=cv2.INTER_AREA):
		# store the target image width, height, and interpolation
		# method used when resizing
		self.width = width
		self.height = height
		self.inter = inter

	def preprocess(self, image):
		# grab the dimensions of the image and then initialize
		# the deltas to use when cropping
		(h, w) = image.shape[:2]
		dW = 0
		dH = 0

		# if the width is smaller than the height, then resize
		# along the width (i.e., the smaller dimension) and then
		# update the deltas to crop the height to the desired
		# dimension
		if w < h:
			image = imutils.resize(image, width=self.width,
				inter=self.inter)
			dH = int((image.shape[0] - self.height) / 2.0)

		# otherwise, the height is smaller than the width so
		# resize along the height and then update the deltas
		# crop along the width
		else:
			image = imutils.resize(image, height=self.height,
				inter=self.inter)
			dW = int((image.shape[1] - self.width) / 2.0)

		# now that our images have been resized, we need to
		# re-grab the width and height, followed by performing
		# the crop
		(h, w) = image.shape[:2]
		image = image[dH:h - dH, dW:w - dW]

		# finally, resize the image to the provided spatial
		# dimensions to ensure our output image is always a fixed
		# size
		return cv2.resize(image, (self.width, self.height),
			interpolation=self.inter)

# %%
class SimpleDatasetLoader:
	def __init__(self, preprocessors=None):
		# store the image preprocessor
		self.preprocessors = preprocessors

		# if the preprocessors are None, initialize them as an
		# empty list
		if self.preprocessors is None:
			self.preprocessors = []

	def load(self, imagePaths, verbose=-1):
		# initialize the list of features and labels
		data = []
		labels = []

		# loop over the input images
		for (i, imagePath) in enumerate(imagePaths):
			# load the image and extract the class label assuming
			# that our path has the following format:
			# /path/to/dataset/{class}/{image}.jpg
			image = cv2.imread(imagePath)


			# check to see if our preprocessors are not None
			if self.preprocessors is not None:
				# loop over the preprocessors and apply each to
				# the image
				for p in self.preprocessors:
					image = p.preprocess(image)

			# treat our processed image as a "feature vector"
			# by updating the data list followed by the labels
			data.append(image)

			# show an update every `verbose` images
			if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
				print("[INFO] processed {}/{}".format(i + 1,
					len(imagePaths)))

		# return a tuple of the data and labels
		return (np.array(data))

# %%
class ImageToArrayPreprocessor:
	def __init__(self, dataFormat=None):
		# store the image data format
		self.dataFormat = dataFormat

	def preprocess(self, image):
		# apply the Keras utility function that correctly rearranges
		# the dimensions of the image
		return img_to_array(image, data_format=self.dataFormat)

# %%
seg_model = load_model('/content/gdrive/MyDrive/gastric_cancer/segementation_weight.h5')
class_model = tf.keras.models.load_model('/content/gdrive/MyDrive/gastric_cancer/class.h5')

# %%
imgs11 = '/content/gdrive/MyDrive/gastric_cancer/cancer_tissue/stage1/image_0_1376.jpg'
X_test1 = np.zeros((1, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test1 = []
img1 = imread(imgs11)[:,:,:IMG_CHANNELS]

sizes_test1.append([img1.shape[0], img1.shape[1]])
img1 = resize(img1, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
X_test1[0] = img1

# #Predict on train, val and test
# model = load_model('/content/gdrive/MyDrive/gastric cancer/seg_weight.h5')

preds_test = seg_model.predict(X_test1, verbose=1)
fig=plt.figure()
imshow(imgs11)

fig=plt.figure()
plt.imshow(X_test1[0])

preds_test_upsampled1=[]
preds_test_t = (preds_test > 0.5).astype(np.uint8)
preds_test_upsampled1.append(resize(np.squeeze(preds_test_t[0]),  (sizes_test1[0][0], sizes_test1[0][1]), mode='constant',
       preserve_range=True))

plt.imshow(np.squeeze(preds_test_t[0]),cmap='gray');
img=np.expand_dims(preds_test_upsampled1[0],axis=-1)

imageio.imwrite('testmask.jpg',img)


onesegmask=['testmask.jpg']

aap = AspectAwarePreprocessor(64,64)
iap = ImageToArrayPreprocessor()

sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
data = sdl.load(onesegmask, verbose=500)
data = data.astype("float") / 255.0

preds = class_model.predict(data).argmax(axis=1)

print(classNames[preds[0]])
# Out:
# 1/1 [==============================] - 0s 22ms/step
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 1/1 [==============================] - 0s 18ms/step
# stage 1
